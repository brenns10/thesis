# %% [markdown]
# # Box Plots!
#
# This notebook creates box plots for CSVs output by the experiments.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
def get_mbps(fn):
    with open(fn) as f:
        l = list(csv.reader(f))
    return np.array([int(x[-1]) / 1000000 for x in l])

# %%
def plot_comparison(name):
    ctrl = get_mbps('%s.control.csv' % name)
    nat = get_mbps('%s.nat.csv' % name)
    vpn = get_mbps('%s.vpn.csv' % name)
    fig, ax = plt.subplots()
    ax.boxplot([ctrl, nat, vpn], labels=['Control', 'NAT', 'VPN'])
    ax.set_ylabel('Throughput (Mbps)')
    ax.set_title('Throughput Comparison (%s)' % name)

# %%
plot_comparison('easy')

# %%
plot_comparison('lossy')
