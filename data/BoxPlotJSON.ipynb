# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv

import output

# %%
output.plot_comparison('lossy')
# Out:
# [30, 30, 30, 30, 30, 30]

# %%
output.plot_comparison('easy')
# Out:
# [30, 30, 30, 30, 30, 30]
